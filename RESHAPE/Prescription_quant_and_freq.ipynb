# %% [markdown]
# # Extracting prescription quantity and frequency.
# The purpose of this notebook is to develop a script to extract presctiption quantity and frequency from the free-test field `medicationdosage` in the `tbl_srprimarycaremedication` table.
#
# Some pharmacy lingo will be needed. The initialisms below might be spearated by periods, `.`, or slashes, `/`, and are sometimes capitalised. They can also be concatonated without spaces, e.g. achs = ac + hs = before meals and at bedtime.
# | Initialism | Meaning |
# | ------- | ------- |
# | a | ante, before |
# | ac | ante cibum (before food) |
# | ad lib | as desired |
# | am | in the morning |
# | aq | aqua, take with water |
# | bib | drink |
# | bd, bds, bid | bis die (twice daily) |
# | et | and |
# | c\* | with \* (where \* stands for the other thing) |
# | cap | capsule |
# | h | hour |
# | hs | bedtime or half-strength |
# | i, ii, iii, ... | 1, 2, 3, etc. tablets |
# | id | intradermally, through the skin |
# | im | intramuscular, inject into muscle |
# | in | intranasal, through the nose |
# | inh | inhaler |
# | inj | injection |
# | neb | nebuliser, inhalant medication |
# | nbm, npo | nill by mouth |
# | nocte, noct | at night |
# | od | omni die (every day) |
# | om | omni mane (every morning) |
# | on | omni nocte (every night) |
# | p | post, after |
# | pc | post cibum (after food) |
# | pm | in the evening |
# | pn | per neb, by nebulizer |
# | po | per os, orally, by mouth |
# | pr | rectally
# | prn | pro re nata (when required) |
# | q\* | every \* (where \* is a wildcard for a timepoints or  intervals, e.g. q2h = every 2 hours, q1d = qd = every day, qam = every morning) |
# | qds, qid | quater die sumendum (to be taken four times daily) |
# | qod | every other day |
# | qs | a sufficient amount |
# | qqh | quarta quaque hora (every four hours) |
# | s\* | sans\*, without\* (where \* stands for the other thing) |
# | sc | subcutaneous, inject under the skin |
# | stat | immediately |
# | syr | syrup |
# | tab | tablet |
# | tds, tid | ter die sumendum (to be taken three times daily) |
# | u | unit |
# | ud | as directed |
# | w\* | with \* (where \* stands for the other thing) |
# | wf | with food |
# | x\* | if \* is a number, then \*-many tablets. If \* is a number and/or letter, then \*-many tablets per interval (e.g. d = day) or \*-many intervals |
#
#
# Sources:
#
# - https://bnf.nice.org.uk/about/abbreviations-and-symbols/
# - https://www.nhs.uk/nhs-app/nhs-app-help-and-support/health-records-in-the-nhs-app/abbreviations-commonly-found-in-medical-records/
# - https://www.drugs.com/article/prescription-abbreviations.html#
# - https://chartercollege.edu/news-hub/72-abbreviations-every-pharmacy-tech-needs-know/

# %% [markdown]
# ## Strategy
#
# ### Morning, evening, before bed, etc.
# I want a total count of tablets per day so I need to combine the morning, evening, etc. prescriptions. My plan is to parse these prescriptions into separate columns that I will later sum:
#
# | n_morning | n_evening | n_night | n_bedtime | n_mealtime\* |
# | --------- | --------- | ------- | --------- | ------------ |
# | ...       | ...       | ...     | ...       | ...          |
#
# \*`n_ MEALTIME ` will include "before food", "after food", and "with food".
#
#
# ### Units vs tablets.
# I will treat a tablet as a unit so that there is a common language.

# %% [markdown]
# Install packages.

# %%
#######################
## Install packages. ##
#######################
library( pacman )
pacman::p_load( bigrquery, tidyverse, readr )
bq_auth()

# %% [markdown]
# Set and load requisites.

# %%
##############################
## Set and load requisites. ##
##############################

# Setup connection to GCP.
project_id <- "yhcr-prd-phm-bia-core"
con <- DBI::dbConnect( drv = bigquery(), project = project_id )

# Define R tibbles from GCP tables.
r_tbl_BNF_DMD_SNOMED_lkp <- dplyr::tbl( con, "CB_LOOKUPS.tbl_BNF_DMD_SNOMED_lkp" )
r_tbl_srprimarycaremedication <- dplyr::tbl( con, "CB_FDM_PrimaryCare_V7.tbl_srprimarycaremedication" )

# Clinical code lists (BNF, SNOMED-CT, etc).
codes_BNF_meds_of_interest <-
    readr::read_csv(file = 'ciaranmci-bnf-section-61-drugs-for-diabetes-207573b7.csv',
                    col_types = cols( code = col_character(), term = col_character() ) )$code
names_meds_of_interest <-
    r_tbl_BNF_DMD_SNOMED_lkp %>%
    dplyr::filter( BNF_Code %in% codes_BNF_meds_of_interest ) %>%
    dplyr::select( DMplusD_ProductDescription )

# %% [markdown]
# Apply transforms to the free-text in the `medicationdosage` column to get the contents into a machine-readable format.

# %%
n_row_display <- 200

qry <- r_tbl_srprimarycaremedication %>%
# Select every record that has a prescription for any diabetes medication.
dplyr::inner_join( names_meds_of_interest, by = join_by( nameofmedication == DMplusD_ProductDescription ) ) %>%
# Filter out all 'as directed' dosages.
dplyr::filter( sql( 'NOT CONTAINS_SUBSTR(medicationdosage, \'directed\' )' ) ) %>%
# Filter for tablets and capsules, only.
dplyr::filter( medicationquantity %LIKE% '%tablet%' %OR% medicationquantity %LIKE% '%capsule%' ) %>%
# Select unique `medicationdosage` values, only.
dplyr::select( medicationdosage ) %>%
dplyr::distinct() %>%

#####################
## Transformations ##
#####################
###dplyr::mutate_at(                      # Use dplyr::mutate_at() if I am replacing the column. Otherwise, use dplyr::mutate().
###    .vars = vars( medicationdosage )
###    ,funs(
dplyr::mutate(
    transformed = 
        medicationdosage %>%
        # Transform X: Remove periods, `.`.
        ###stringr::str_replace(., "\\.",              "" ) %>%
        stringr::str_replace("\\.",              "" ) %>%
        
        # Transform X: Make everything lower case.
        stringr::tolower() %>%
        
        # Transform X: "and " to +.
        stringr::str_replace( "\\ (and)|\\&\\ ",               " + " ) %>%
        
        # Transfrom X: Tidy away typos.
        stringr::str_replace( "(ty)[a-z]",              "t" ) %>% # Still experimental. This is trying to fix typos like "tywo" instead of "two".
        stringr::str_replace( "(afte)r?",                "" ) %>%
        stringr::str_replace( "(befor)e?",               "" ) %>%
        stringr::str_replace( "(me)[a-z]?(al)s?",        "" ) %>%
        stringr::str_replace( "\\ (ime)",                  "" ) %>%
        stringr::str_replace( "\\ (-time)",                "" ) %>%
        stringr::str_replace( "\\ (time)\\ ",              "" ) %>%
        stringr::str_replace( "(eve)[a-z](ing)",              "" ) %>%
        stringr::str_replace( "(m[a-z]?orn?ing)",              "" ) %>%
                
        # Transform X: Handle special case of "for one week".
        stringr::str_replace( "(for)?\\ (one)?1?\\ (week)s?",         " INTERVAL = (1) " ) %>% # Ideally, this set of transforms would handle all the "week1", "week 2", etc. instructions.
        stringr::str_replace( "(for)?\\ (two)?2?\\ (week)s?",         " INTERVAL = (2) " ) %>% 
        stringr::str_replace( "(for)?\\ (three)?3?\\ (week)s?",       " INTERVAL = (3) " ) %>% 
        stringr::str_replace( "(for)?\\ (four)?4?\\ (week)s?",        " INTERVAL = (4) " ) %>% 
        
        # Transfrom X: Homogenise intervals, e.g. hourly, daily.
        stringr::str_replace( "(a day)",                     "daily" ) %>%
        stringr::str_replace( "(aday)",                      "daily" ) %>%
        stringr::str_replace( "(each day)",                "daily" ) %>%
        stringr::str_replace( "(per day)",                "daily" ) %>%
        stringr::str_replace( "/\\ ?(day)",                "daily" ) %>%
        stringr::str_replace( "(every day)",               "daily" ) %>%
        stringr::str_replace( "(^|\\ )(od)\\ ",               "daily" ) %>%
        
        # Transform X: Remove unnecessary 'tablet'.
        stringr::str_replace( "\\ ?(tab)(le[a-z]?t)?s?",       "" ) %>%
        
        # Transform X: Collapse numbers and their units so that the numbers don't get interpretted as counts, later.
        stringr::str_replace( "[0-9]*\\ g\\ |$",       "" ) %>%
    
        # Transform X: Remove unnecessary 'take' and its typos.
        stringr::str_replace( "(ta)[a-z]e?(ing)?n?",               "" ) %>%
    
        # Transform X: Remove unnecessary ' to be '.
        stringr::str_replace( "\\ (to be)\\ ",               "" ) %>%
        
        # Transform X: Remove unnecessary 'use '.
        stringr::str_replace( "(use)[0-9]?\\ ",             "" ) %>%
        
        # Transform X: Ignore 'working up to' and its variants.
        #stringr::str_replace( "work(ing)? up to ",  "" ) %>% # This might be important information, so I'll leave it in for now.
        #stringr::str_replace( "wean up gently to",  "" ) %>%
        #stringr::str_replace( "work up slowly to",  "" ) %>%
        # (up)\\ ?(titrate)
        
        # Transform X: Ignore notions of 'with'.
        stringr::str_replace( "(with)/?\\ ?(the)?", "" ) %>%
        stringr::str_replace( "(w/)\\ ",                "" ) %>%
        stringr::str_replace( "\\ c\\ ",                "" ) %>%
        stringr::str_replace( "\\ ?w\\ ",             "" ) %>%
        
        # Transform X: Ignore 'as needed' and similar.
        stringr::str_replace( "(as needed)",          "" ) %>%
        stringr::str_replace( "(when needed)",        "" ) %>%
        stringr::str_replace( "(as necessary)",       "" ) %>%
        stringr::str_replace( "(when necessary)",     "" ) %>%
        stringr::str_replace( "(as required)",        "" ) %>%
        stringr::str_replace( "(when required)",      "" ) %>%
        stringr::str_replace( "(when req)",           "" ) %>%
        stringr::str_replace( "(as desired)",         "" ) %>%
        stringr::str_replace( "(when desired)",       "" ) %>%
        stringr::str_replace( "(ad lib)",             "" ) %>%
        stringr::str_replace( "( qs )",               "" ) %>%
        
        # Transform X: Fix typos.
        stringr::str_replace( "!",                  "1" ) %>%
        
        # Transform X: Convert number words to digits.
        stringr::str_replace( "(1/2)|(half)|(every alternate day)|(alt days)|(every other day)",         " QUANT = (0.5) " ) %>%
        stringr::str_replace( "(one)|(\\ |^)i\\ |(whole)",                     " QUANT = (1) " ) %>%
        stringr::str_replace( "(two)|(\\ |^)ii\\ ",                     " QUANT = (2) " ) %>%
        stringr::str_replace( "(three)|(\\ |^)iiii\\ ",                   " QUANT = (3) " ) %>%
        stringr::str_replace( "(four)|(\\ |^)iv\\ ",                    " QUANT = (4) " ) %>% # I hope patients don't take more than 4 of the same tablet in a day.
        
        # Transform X: Remove leading 'x' in front of digits.
        stringr::str_replace( "x\\ ?1",                    " QUANT = (1) " ) %>%
        stringr::str_replace( "x\\ ?2",                    " QUANT = (2) " ) %>%
        stringr::str_replace( "x\\ ?3",                    " QUANT = (3) " ) %>%
        stringr::str_replace( "x\\ ?4",                    " QUANT = (4) " ) %>%
        
        # Transform X: Leading quantities.
        stringr::str_replace( "1\\ ",                     " QUANT = (1) " ) %>%
        stringr::str_replace( "2\\ ",                     " QUANT = (2) " ) %>%
        stringr::str_replace( "3\\ ",                     " QUANT = (3) " ) %>%
        stringr::str_replace( "4\\ ",                     " QUANT = (4) " ) %>%
        stringr::str_replace( "5\\ ",                     " QUANT = (5) " ) %>%
        
        # Transform X: Convert multiplier words to digits. I assume a daily base for my frequency, e.g. daily = 1.
        stringr::str_replace( "\\ ?(times)",                              "" ) %>%
        stringr::str_replace( "(twice)|(2x)|((\\ x)?(bd)s?\\ ?)",           " FREQ = (2) " ) %>%
        stringr::str_replace( "(once)|(daily)|((\\ x)?(od)s?\\ ?)",       " FREQ = (1) " ) %>% # The preceding space is not optional because, otherwise, we transform "blood" to "blo FREQ = (1)".
        stringr::str_replace( "\\ ?x?[0-9]?(td)s?\\ ?",                   " FREQ = (3) " ) %>%
        stringr::str_replace( "(every 8 hours)",                          " FREQ = (3) " ) %>%
        stringr::str_replace( "\\ ?x?[0-9]?(qd)s?\\ ?",                   " FREQ = (4) " ) %>%
        
         # Transform X: Convert time-of-day instructions to latin capitalised initialisms, or latin words.
        stringr::str_replace( "(in the morning)",          " WHEN = (A.M.) " ) %>%
        stringr::str_replace( "(at )?(morning)[a-z]?",     " WHEN = (A.M.) " ) %>%
        stringr::str_replace( "\\ [0-9]?(o.m.)(\\ |$)",    " WHEN = (A.M.) " ) %>%
        stringr::str_replace( "\\ [0-9]?(om)(\\ |$)",      " WHEN = (A.M.) " ) %>%
        stringr::str_replace( "(\\ |^[0-9])?(am)(\\ |$)",  " WHEN = (A.M.) " ) %>%
        stringr::str_replace( "(in the evening)",          " WHEN = (P.M.) " ) %>%
        stringr::str_replace( "(midday)",                  " WHEN = (P.M.) " ) %>%
        stringr::str_replace( "(evening)[a-z]?",           " WHEN = (P.M.) " ) %>%
        
        stringr::str_replace( "\\ ?(pm)$?",                " WHEN = (P.M.) " ) %>%
        stringr::str_replace( "(noct)e?",                  " WHEN = (NOCTE) " ) %>%
        stringr::str_replace( "(in the night)",            " WHEN = (NOCTE) " ) %>%
        stringr::str_replace( "(at night)",                " WHEN = (NOCTE) " ) %>%
        stringr::str_replace( "(night)[a-z]?",             " WHEN = (NOCTE) " ) %>%
        stringr::str_replace( "\\ [0.9]?(o.n.)(\\ |$)",                  " WHEN = (NOCTE) " ) %>% # Not confident about replacing "on" with NOCTE.
        stringr::str_replace( "(wf)",                                                              " WHEN = (MEALTIME) " ) %>%
        stringr::str_replace( "(before)?(after)?(with)?\\ (food)s?",              " WHEN = (MEALTIME) " ) %>%
        stringr::str_replace( "(before)?(after)?(with)?\\ (meal)s?",              " WHEN = (MEALTIME) " ) %>%
        stringr::str_replace( "(before)?(after)?(with)?\\ (break)\\ ?(fast)s?",   " WHEN = (MEALTIME) " ) %>%
        stringr::str_replace( "(before)?(after)?(with)?\\ (lunch)(time)?",        " WHEN = (MEALTIME) " ) %>%
        stringr::str_replace( "(eve)(ning)?\\ (meal)",                             " WHEN = (MEALTIME) " ) %>%
        stringr::str_replace( "(before)?(after)?(with)?\\ (dinner)s?",            " WHEN = (MEALTIME) " ) %>%
        stringr::str_replace( "(before)?(after)?(with)?\\ (supper)s?",            " WHEN = (MEALTIME) " ) %>%
        stringr::str_replace( "(before)?(after)?(with)?\\ (tea)\\ ?(time)?s?(\\ meal)?",     " WHEN = (MEALTIME) " ) %>%
        
       
        
        # Transform X: Remove schpeel about "your practice will contact you..."
        stringr::str_replace( "(your practice will contact you).*$", "" ) %>%
        
        # Transform X: Remove schpeel about "whilst taking steriods...
        stringr::str_replace( "(whilst taking steroids)",    "" ) %>%
        
       
        
        
        # Transfrom X: Remove typos that results from other transforms.
        stringr::str_replace( "( in the )",                     "" ) %>%
        stringr::str_replace( "\\ at\\ ",                     "" ) %>%
        stringr::str_replace( "\\ (time)",                     "" ) %>%
        stringr::str_replace( "(every)",                     "" ) %>%
        stringr::str_replace( "(main)",                    "" ) %>%
        stringr::str_replace( "(each)",                    "" ) %>%
        stringr::str_replace( "\\ \\ ",                        " " ) %>%
        stringr::str_replace( "\\ -\\ ",                       " " ) %>%
        stringr::str_replace( "^?\\ a\\ ",                       " " )
        
    ###)
) %>%
# Filter out prosaic dosages that give week-by-week explanations.
dplyr::filter( sql( 'NOT REGEXP_CONTAINS(medicationdosage, r\'w(e*)?ks?\\ ?(-)?[0-9]\' )' ) )%>% dplyr::filter( medicationdosage != "" ) %>% distinct() %>% collect() %>% head( n = n_row_display ); qry


### DISPLAY ###

options(repr.matrix.max.rows = n_row_display)
#qry %>% dplyr::filter( medicationdosage != "" ) %>% distinct() %>% collect() %>% head( n = n_row_display )

##############
### TRICKY ###
##############
# 1-2 IN THE MORNING
# Out:
#     medicationdosage
# 1   Take Half A Tablet Daily With Breakfast
# 2   2 before breakfast and another 2 before teatime meal
# 3   take one at teatime
# 4   Take 1 daily
# 5   Take 2 daily
# 6   half tab twice a day
# 7   Two Tablets To Be Taken With Breakfast And Two To be Taken With Evening Meal
# 8   TAKE 2 TABS IN AM & 1 TAB AT NIGHT
# 9   one bd with meal
# 10  take one OM
# 11  2 OM  2 Lunch time 2 teatime  ( with meal)
# 12  one bd two lunchtime
# 13  Take one in the morning and one in the evening .
# 14  take two daily with or after food
# 15  1 To be taken 3 times a day
# 16  OD ONE WEEK THEN ONE TWICE DAILY
# 17  two tablets in the morning and two tablets with evening meal
# 18  take 2 tablets at breakfast and two tablets at tea-time
# 19  two evening
# 20  Take one in the evening
# 21  one to be taken BD
# 22  1 AM +1 AND HALF AT TEA TIME
# 23  METFORMIN - take 2 once daily with breakfast
# 24  2 tablet Daily
# 25  2 bd ( 160mg bd )
# 26  TAKE ONE TABLET(S) TWICE A DAY
# 27  take 2 twice a day after meals
# 28  Take one tab twice daily tablets following each meal
# 29  take 3 tablets after evening meal
# 30  4 on
# 31  one two Times Daily
# 32  2 TWICE A DAY BEFORE FOOD
# 33  take one half daily
# 34  take four with pm meal
# 35  Take 2 in the morning and 1 at night
# 36  80mg Every Day
# 37  2  To be taken 2  Times Daily with meals
# 38  1 TWICE A DAY 20 MINS BEFOR FOOD
# 39  METFORMIN: Take one after breakfast and two afer evening meal
# 40  1 Every Day4 with evening meal
# 41  1 AFTER BREAKFAST AND 1 AFTER TEA
# 42  take two tablets at breakfast two tablets at teatime
# 43  take 2 daily in the evening.
# 44  one To be taken each morning and One tablet in the afternoon
# 45  take one  bd
# 46  take two  daily after main meal
# 47  take 2 tabs od
# 48  take one tablet with food twice daily
# 49  Take one tablet after breakfast and one tablet after evening meal.
# 50  Three daily
# 51  take one twice aday with food - metformin
# 52  1 To be taken TwoTimes Daily
# 53  take 4 a day as advised
# 54  1 THREE TIMES A DAY BEFORE  MEALS
# 55  ONE  A DAY BEFORE BREAKFAST and before tea
# 56  Take one once daily
# 57  2 tabs in the morning two evening.
# 58  1g (2 tablets ) twice a day with food.
# 59  once daily with evening meal.
# 60  take one 4  times/day
# 61  one in morning and 2  with evening meal
# 62  1 Every Day for a week then two daily
# 63  1 om and 2 with evening
# 64  take once daily increase by one a week until taking two twice a day
# 65  4 once daily
# 66  One daily then 2 daily after 1 week then review with own GP
# 67  one and half tab Twice Daily
# 68  1 TABLET TWICE A DAY 1/2 HOUR BEFORE MEAL
# 69  take one am and one pm
# 70  1/2 a tablet  twice a day.
# 71  One To Be Taken In The Morning And One To Be Taken At Teatime
# 72  two with breakfast and 2 with Evening meal
# 73  two tablets in the morning and 2 at night
# 74  take TWO 2 times/day
# 75  to take 4 tablets with evening meal
# 76  1 dialy
# 77  2 in the evening with food
# 78  two  in evening
# 79  3 or 4 tablets daily with food depending on tolerance
# 80  two with biggest meal
# 81  one Twice Daily with food
# 82  take two at  teatime
# 83  Take ONE tablet in a MORNING with breakfast. review after 8 weeks
# 84  1 To be taken Twice Daily *Acute rx issued to replace lost tablets* PLEASE KEEP MEDICATION IN A SAFE PLACE
# 85  take 1/2 tablet before breakfast & 1/2 tablet before eve meal
# 86  2 twice daly
# 87  one tablet morning and one and one half tablet evening
# 88  Take 2 tablets daily with evening meal
# 89  To be taken Each Night
# 90  ONE bd
# 91  take one 2 times/day- WITH MEAL
# 92  Take ONE tablet in a MORNING with breakfast and a full glass of water
# 93  one a day in morning
# 94  1 WITH BREAKFAST 2 WITH PM MEAL
# 95  One tablet a day with food
# 96  1 daily after largest meal
# 97  metformin: take two once daily
# 98  take one before breakfast and one before evening meal.
# 99  Day(s)
# 100 take 2 tabs at evening meal
# 101 METFORMIN: Take one daily at breakfast
# 102 one table twice  daily with meals
# 103 take one tablet once a day for 1 week then increase to 2 daily
# 104 2 With Breakfast 2 With Evening Meal
# 105 take 2 tablets ONCE daily with evening meal
# 106 i daily
# 107 take 1 tablet morning and half tablet teatime
# 108 take two in the morning and two with supper
# 109 ONCE DAILY TO CONTROL DIABETES
# 110 two tablets Three Times Daily
# 111 take 2 three times  a day
# 112 METFORMIN: Take 3 daily after evening meal
# 113 2 daily.
# 114 TWO DAILY WITH MAIN MEAL-FOR DIABETES.
# 115 2 MANE AND 1 AT TEATIME
# 116 1 Three Times Daily WITH OR AFTER MEALS
# 117 take two daily with main meal for Diabetes
# 118 take one tablet with or after evening meal.
# 119 2am 2 pm
# 120 2 tablet in a morning and 2 tabs in evening
# 121 take two  tab  daily
# 122 take 2 tab breakfast and 2 tab teatime with food.
# 123 one tablet daily for 1st week then increase to twice aday 2nd week
# 124 Take two before breakfast and two before evening meal
# 125 2 tablets (1000mgs)daily with evening meals - metformin
# 126 whole tablet At Morning and half at tea time
# 127 take two in am and one in pm
# 128 AFTER BREAKFAST AND AFTER TEA
# 129 40mg Twice Daily
# 130 take 2 tablets with food in the evening
# 131 [08:00-TWO tablets pre-breakfast]
# 132 Take TWO tablets with lunch and TWO tablets with evening meal.
# 133 one om 2 with pm meal
# 134 Take one tablet morning and 2 at night
# 135 4  with evening meal
# 136 take  two tablet with breakfast & two with tea
# 137 1 WITH BREAKFAST
# 138 take one with main meal increase gradually to 4 tablets
# 139 take one daily for 2 weeks and if tolerated then increase to 2 daily
# 140 2 Evening
# 141 Take one tablet in the morning with breakfast and two tablets in the evening with the evening meal
# 142 TAKE ONE TABLET DAILY AT LUNCH TIME
# 143 Take two tablet after breakfast and two tablet after evening meal.
# 144 take two in morning & 2 in evening 20 min before food
# 145 take one 2 times/day (breakfast and eveing meal)
# 146 Take ONE tablet in a MORNING with full glass of water
# 147 take one   daily
# 148 2 At Morning and 1 teatime
# 149 take one tablet in morning and two tabs with evening meal
# 150 take one on a morning and one on an evening
# 151 take one daily for 2 weeks and then 2 OD
# 152 take 2 tabs Morning and 2 tabs with evening meal
# 153 Take 1 tablet twice daily with food.
# 154 2TABBD Number of days supply=30
# 155 1BD WITH BREAKFAST AND TEAT TIME MEAL
# 156 take one twice daily to control diabetes
# 157 Take TWO morning ands
# 158 take 3 daily in separate doses
# 159 Take 1 daily as per diabetic nurse advice
# 160 take 2 tablets in morning.
# 161 1 TWICE A DAY AFTER FOOD
# 162 take one with evening meal... (metformin mr)
# 163 take 2 in the morning up to 1 in the evening with meals
# 164 Take two daily (this is the same drug as metformin)
# 165 take  2  tabs twice daily
# 166 take one tablet once a day with food for 1 week then take one tablet twice a day with food.
# 167 2 with breakfast 1with lunch 1 with pm meal
# 168 take one with or after pm meal
# 169 TAKE ONCE DAILY FOR ONE WEEK THEN INCREASE TO TWICE A DAY
# 170 take one tablet three times daily (please note increased dose)
# 171 ONE TABLET MORNING AND TWO EVENING
# 172 1 TABLET IN THE MORNING
# 173 take 2 with breakfast and 2 with Evening meal
# 174 take 2 bd with food.
# 175 Take TWO in the morning and TWO at night
# 176 take two daily with evening meal (METFORMIN LONG ACTING)
# 177 take 2 bddaily
# 178 take two daily.... ( metformin  mr )
# 179 metformin: four with evening meal
# 180 1 DAILY WITH MAIN MEAL FOR 1 WEEKTHEN 1 TWICE A DAY WITH MEALS FOR 1 WEEK THEN 1 THREE TIMES A DAY WITH FOOD FOR A WEEKTHEN 2 TWICE A DAY WITH FOOD
# 181 take 1after meal
# 182 one in the morning and  one  at  lunchtime
# 183 Take ONE tablet daily increase by 1 tablet every 7 days until reach maximum dose of 4 tablets a day with main meal
# 184 take onetab Twice daily after food
# 185 2 morning and night
# 186 one with morning meal and two with evening meal (three in tottal)
# 187 2 in morning 1 teatime
# 188 TAKE HALF A TABLET EACH MORNING
# 189 take one tablet with main meal daily
# 190 Two To Be Taken Twice A Day After Food
# 191 take 1 in morning  and two in evening
# 192 2 with breakfast two with dinner.
# 193 METFORMIN: Take one with breakfast and one with eveing meal
# 194 Take one daily for 2 weeks hen increase to Twice Daily with food
# 195 2 mane and one afternoon
# 196 4 TO BE TAKEN WITH EVENING MEAL
# 197 2 IN THE MORNING & 1 AT TEATIME
# 198 two morning then one nightly
# 199 two morning one in the evening.
# 200 take TWO  daily-FOR DIABETES
#     transformed
# 1    QUANT = (0.5) FREQ = (1) WHEN = (MEALTIME)
# 2    QUANT = (2) WHEN = (MEALTIME) + another QUANT = (2) WHEN = (MEALTIME)
# 3    QUANT = (1) WHEN = (MEALTIME)
# 4    QUANT = (1) FREQ = (1)
# 5    QUANT = (2) FREQ = (1)
# 6    QUANT = (0.5)  FREQ = (2)  FREQ = (1)
# 7    QUANT = (2) WHEN = (MEALTIME) +  QUANT = (2)
# 8    QUANT = (2) in WHEN = (A.M.) + QUANT = (1) WHEN = (NOCTE)
# 9    QUANT = (1)  FREQ = (2)
# 10   QUANT = (1) WHEN = (A.M.)
# 11   QUANT = (2) WHEN = (A.M.)  QUANT = (2) WHEN = (MEALTIME) QUANT = (2) WHEN = (MEALTIME)  ( )
# 12   QUANT = (1)  FREQ = (2) QUANT = (2) WHEN = (MEALTIME)
# 13   QUANT = (1) +  QUANT = (1)
# 14   QUANT = (2)  FREQ = (1) or fo FREQ = (1)
# 15   QUANT = (1) QUANT = (3) FREQ = (1)
# 16   FREQ = (1) INTERVAL = (1) then QUANT = (1)  FREQ = (2)  FREQ = (1)
# 17   QUANT = (2) +  QUANT = (2)
# 18   QUANT = (2)WHEN = (MEALTIME) +  QUANT = (2) WHEN = (MEALTIME) -time
# 19   QUANT = (2)
# 20   QUANT = (1)
# 21   QUANT = (1)  FREQ = (2)
# 22   QUANT = (1) WHEN = (A.M.) + QUANT = (1) +  QUANT = (0.5) WHEN = (MEALTIME)
# 23  metformin  QUANT = (2) FREQ = (1)  FREQ = (1) WHEN = (MEALTIME)
# 24   QUANT = (2) FREQ = (1)
# 25   QUANT = (2) FREQ = (2) ( 160mg FREQ = (2) )
# 26   QUANT = (1) (s) FREQ = (2)  FREQ = (1)
# 27   QUANT = (2) FREQ = (2)  FREQ = (1)
# 28   QUANT = (1)  FREQ = (2)  FREQ = (1) following
# 29   QUANT = (3)
# 30   QUANT = (4) on
# 31   QUANT = (1)  QUANT = (2)  FREQ = (1)
# 32   QUANT = (2) FREQ = (2)  FREQ = (1)  fo FREQ = (1)
# 33   QUANT = (1)  QUANT = (0.5)  FREQ = (1)
# 34   QUANT = (4) WHEN = (P.M.)
# 35   QUANT = (2) +  QUANT = (1) WHEN = (NOCTE)
# 36  80mg FREQ = (1)
# 37   QUANT = (2)  QUANT = (2)  FREQ = (1)
# 38   QUANT = (1) FREQ = (2)  FREQ = (1) 20 mins fo FREQ = (1)
# 39  metformin:  QUANT = (1)  WHEN = (MEALTIME) +  QUANT = (2) afer
# 40   QUANT = (1) FREQ = (1) QUANT = (4)
# 41   QUANT = (1) WHEN = (MEALTIME) +  QUANT = (1) WHEN = (MEALTIME)
# 42   QUANT = (2) WHEN = (MEALTIME)  QUANT = (2) WHEN = (MEALTIME)
# 43   QUANT = (2) FREQ = (1)
# 44   QUANT = (1)  +  QUANT = (1) noon
# 45   QUANT = (1)  FREQ = (2)
# 46   QUANT = (2)  FREQ = (1)
# 47   QUANT = (2) FREQ = (1)
# 48   QUANT = (1) fo FREQ = (1) FREQ = (2)  FREQ = (1)
# 49   QUANT = (1)  WHEN = (MEALTIME) +  QUANT = (1)
# 50   QUANT = (3)  FREQ = (1)
# 51   QUANT = (1)  FREQ = (2)  FREQ = (1) fo FREQ = (1) metformin
# 52   QUANT = (1) QUANT = (2) FREQ = (1)
# 53   QUANT = (4) FREQ = (1) as advised
# 54   QUANT = (1) QUANT = (3)  FREQ = (1)
# 55   QUANT = (1)  FREQ = (1)  WHEN = (MEALTIME) +  WHEN = (MEALTIME)
# 56   QUANT = (1)  FREQ = (1)  FREQ = (1)
# 57   QUANT = (2) QUANT = (2)
# 58  1g ( QUANT = (2) ) FREQ = (2)  FREQ = (1) fo FREQ = (1)
# 59   FREQ = (1)  FREQ = (1)
# 60   QUANT = (1)  QUANT = (4) FREQ = (1)
# 61   QUANT = (1) in +  QUANT = (2)
# 62   QUANT = (1) FREQ = (1) for week then QUANT = (2)  FREQ = (1)
# 63   QUANT = (1) WHEN = (A.M.) +  QUANT = (2)
# 64   FREQ = (1)  FREQ = (1) increase by QUANT = (1) week until  QUANT = (2)  FREQ = (2)  FREQ = (1)
# 65   QUANT = (4) FREQ = (1)  FREQ = (1)
# 66   QUANT = (1)  FREQ = (1) then QUANT = (2) FREQ = (1)  INTERVAL = (1) then revieown gp
# 67   QUANT = (1) +  QUANT = (0.5)  FREQ = (2)  FREQ = (1)
# 68   QUANT = (1) FREQ = (2)  FREQ = (1)  QUANT = (0.5) hour
# 69   QUANT = (1) WHEN = (A.M.) +  QUANT = (1) WHEN = (P.M.)
# 70   QUANT = (0.5)  FREQ = (2)  FREQ = (1)
# 71   QUANT = (1) +  QUANT = (1) WHEN = (MEALTIME)
# 72   QUANT = (2) WHEN = (MEALTIME) +  QUANT = (2)
# 73   QUANT = (2) +  QUANT = (2) WHEN = (NOCTE)
# 74   QUANT = (2)  QUANT = (2) FREQ = (1)
# 75  to  QUANT = (4)
# 76   QUANT = (1) dialy
# 77   QUANT = (2) fo FREQ = (1)
# 78   QUANT = (2)  in
# ...
# 128  WHEN = (MEALTIME) +  WHEN = (MEALTIME)
# 129 40mg FREQ = (2)  FREQ = (1)
# 130  QUANT = (2) fo FREQ = (1)
# 131 [08:00- QUANT = (2) pre-breakfast]
# 132  QUANT = (2) WHEN = (MEALTIME) +  QUANT = (2)
# 133  QUANT = (1) WHEN = (A.M.) QUANT = (2) WHEN = (P.M.)
# 134  QUANT = (1)  +  QUANT = (2) WHEN = (NOCTE)
# 135  QUANT = (4)
# 136   QUANT = (2) WHEN = (MEALTIME)  + QUANT = (2) WHEN = (MEALTIME)
# 137  QUANT = (1) WHEN = (MEALTIME)
# 138  QUANT = (1)  increase gradually to 4
# 139  QUANT = (1)  FREQ = (1)  INTERVAL = (2) + if tolerated then increase to QUANT = (2) FREQ = (1)
# 140  QUANT = (2)
# 141  QUANT = (1) WHEN = (MEALTIME) +  QUANT = (2)
# 142  QUANT = (1)  FREQ = (1) WHEN = (MEALTIME)
# 143  QUANT = (2)  WHEN = (MEALTIME) +  QUANT = (2)
# 144  QUANT = (2) in  + QUANT = (2) in 20 min fo FREQ = (1)
# 145  QUANT = (1)  QUANT = (2) FREQ = (1) (breakfast + eveing )
# 146  QUANT = (1) in full glass of water
# 147  QUANT = (1)   FREQ = (1)
# 148  QUANT = (2) +  QUANT = (1) WHEN = (MEALTIME)
# 149  QUANT = (1) in +  QUANT = (2)
# 150  QUANT = (1) on +  QUANT = (1) on an
# 151  QUANT = (1)  FREQ = (1)  INTERVAL = (2) + then QUANT = (2) FREQ = (1)
# 152  QUANT = (2) +  QUANT = (2)
# 153  QUANT = (1) FREQ = (2)  FREQ = (1) fo FREQ = (1)
# 154 2 FREQ = (2) number of days supply=30
# 155 1 FREQ = (2) WHEN = (MEALTIME) + WHEN = (MEALTIME) t
# 156  QUANT = (1)  FREQ = (2)  FREQ = (1) to control diabetes
# 157  QUANT = (2)  + s
# 158  QUANT = (3) FREQ = (1) in separate doses
# 159  QUANT = (1) FREQ = (1) as per diabetic nurse advice
# 160  QUANT = (2) in
# 161  QUANT = (1) FREQ = (2)  FREQ = (1)  fo FREQ = (1)
# 162  QUANT = (1)  (metformin mr)
# 163  QUANT = (2) up to QUANT = (1)
# 164  QUANT = (2)  FREQ = (1) (this is the same drug as metformin)
# 165   QUANT = (2)  FREQ = (2)  FREQ = (1)
# 166  QUANT = (1)  FREQ = (1)  FREQ = (1) fo FREQ = (1) INTERVAL = (1) then  QUANT = (1)  FREQ = (2)  FREQ = (1) fo FREQ = (1)
# 167  QUANT = (2) WHEN = (MEALTIME) 1lunch QUANT = (1) WHEN = (P.M.)
# 168  QUANT = (1) or WHEN = (P.M.)
# 169  FREQ = (1)  FREQ = (1)  INTERVAL = (1) then increase to FREQ = (2)  FREQ = (1)
# 170  QUANT = (1)  QUANT = (3)  FREQ = (1) (please note increased dose)
# 171  QUANT = (1)  +  QUANT = (2)
# 172  QUANT = (1)
# 173  QUANT = (2) WHEN = (MEALTIME) +  QUANT = (2)
# 174  QUANT = (2) FREQ = (2) fo FREQ = (1)
# 175  QUANT = (2) +  QUANT = (2)  WHEN = (NOCTE)
# 176  QUANT = (2)  FREQ = (1)  (metformin long acting)
# 177  QUANT = (2) FREQ = (2) FREQ = (1)
# 178  QUANT = (2)  FREQ = (1) ( metformin mr )
# 179 metformin: QUANT = (4)
# 180  QUANT = (1) FREQ = (1)   INTERVAL = (1) then QUANT = (1) FREQ = (2)  FREQ = (1)  INTERVAL = (1) then QUANT = (1) QUANT = (3)  FREQ = (1) fo FREQ = (1) for weekthen QUANT = (2) FREQ = (2)  FREQ = (1) fo FREQ = (1)
# 181  QUANT = (1)
# 182  QUANT = (1) +  QUANT = (1)  WHEN = (MEALTIME)
# 183  QUANT = (1)  FREQ = (1) increase by QUANT = (1) 7 days until r maximum dose of QUANT = (4) FREQ = (1)
# 184  QUANT = (1)  FREQ = (2)  FREQ = (1)  fo FREQ = (1)
# 185  QUANT = (2) +  WHEN = (NOCTE)
# 186  QUANT = (1)  +  QUANT = (2)  ( QUANT = (3) in tot)
# 187  QUANT = (2) in  QUANT = (1) WHEN = (MEALTIME)
# 188  QUANT = (0.5)
# 189  QUANT = (1)   FREQ = (1)
# 190  QUANT = (2)  FREQ = (2)  FREQ = (1)  fo FREQ = (1)
# 191  QUANT = (1) in  +  QUANT = (2) in
# 192  QUANT = (2) WHEN = (MEALTIME)  QUANT = (2) WHEN = (MEALTIME)
# 193 metformin:  QUANT = (1) WHEN = (MEALTIME) +  QUANT = (1) eveing
# 194  QUANT = (1)  FREQ = (1)  INTERVAL = (2) hen increase to FREQ = (2)  FREQ = (1) fo FREQ = (1)
# 195  QUANT = (2) mane +  QUANT = (1) noon
# 196  QUANT = (4)
# 197  QUANT = (2) + QUANT = (1)WHEN = (MEALTIME)
# 198  QUANT = (2)  then QUANT = (1)  WHEN = (NOCTE) y
# 199  QUANT = (2)  QUANT = (1)
# 200  QUANT = (2)  FREQ = (1) -for diabetes

# %% [markdown]
# Work with the `medicationquantity` columns to see if you can determine the expected prescription duration.

# %%
qry <- r_tbl_srprimarycaremedication %>%
# Select every record that has a prescription for any diabetes medication.
dplyr::inner_join( names_meds_of_interest, by = join_by( nameofmedication == DMplusD_ProductDescription ) ) %>%
# Filter out all 'as directed' dosages.
dplyr::filter( sql( 'NOT CONTAINS_SUBSTR(medicationdosage, \'directed\' )' ) ) %>%
# Filter for tablets and capsules, only.
dplyr::filter( medicationquantity %LIKE% '%tablet%' %OR% medicationquantity %LIKE% '%capsule%' ) %>%
# Select unique `medicationdosage` values, only.
dplyr::select( medicationquantity ) %>%
dplyr::distinct() %>%
dplyr::mutate(
    transformed = 
        medicationquantity %>%
        
        # Transform X: Remove parentheses.
        stringr::str_replace("\\(?\\)?",              "" ) %>%
        
        # Transform X: Make everything lower case.
        stringr::tolower() %>%
        
        # Get rid of the drug mass, e.g. grams and mg.
        stringr::str_replace( "[0-9]*\\ ?(mg)|(gram)s?",              "" ) %>%
        
        
        # Transform X: Remove parentheses.
        stringr::str_replace( "(tab)(let)?s?",              "" ) %>%
        
        # Transform " pack of " to "*", which is used more often, it seems.
        stringr::str_replace( "\\ (pack)s?\\ (of)\\ ",              "*" ) %>%
        
        # Transform the implied multiplications.
        stringr::str_replace( "(^1\\*|x)|(\\*1\\ )",              " MULTI = (1 TIMES) " ) %>%
        stringr::str_replace( "(^2\\*|x)|(\\*2\\ )",              " MULTI = (2 TIMES) " ) %>%
        stringr::str_replace( "(^3\\*|x)|(\\*3\\ )",              " MULTI = (3 TIMES) " ) %>%
        stringr::str_replace( "(^4\\*|x)|(\\*4\\ )",              " MULTI = (4 TIMES) " ) %>%
        stringr::str_replace( "(^5\\*|x)|(\\*5\\ )",              " MULTI = (5 TIMES) " ) %>%
        stringr::str_replace( "(^6\\*|x)|(\\*6\\ )",              " MULTI = (6 TIMES) " ) %>%
        stringr::str_replace( "(^7\\*|x)|(\\*7\\ )",              " MULTI = (7 TIMES) " ) %>%
        stringr::str_replace( "(^8\\*|x)|(\\*8\\ )",              " MULTI = (8 TIMES) " ) %>%
        stringr::str_replace( "(^9\\*|x)|(\\*9\\ )",              " MULTI = (9 TIMES) " ) %>%
        stringr::str_replace( "(^10\\*|x)|(\\*10\\ )",              " MULTI = (10 TIMES) " ) %>%
        stringr::str_replace( "(^11\\*|x)|(\\*11\\ )",              " MULTI = (11 TIMES) " ) %>%
        stringr::str_replace( "(^12\\*|x)|(\\*12\\ )",              " MULTI = (12 TIMES) " ) %>%
        
        # Find realistic multiples of 28, which is a months' worth of tablets.
        stringr::str_replace( "(^|\\ )?(28)\\ ",              " QUANT = (1 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(56)\\ ",              " QUANT = (2 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(84)\\ ",              " QUANT = (3 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(112)\\ ",             " QUANT = (4 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(140)\\ ",             " QUANT = (5 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(168)\\ ",             " QUANT = (6 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(196)\\ ",             " QUANT = (7 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(224)\\ ",             " QUANT = (8 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(252)\\ ",             " QUANT = (9 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(280)\\ ",             " QUANT = (10 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(308)\\ ",             " QUANT = (11 MONTHS) " ) %>%
        stringr::str_replace( "(^|\\ )?(336)\\ ",             " QUANT = (12 MONTHS) " ) %>%
        
        # TIdy up the implied arithemtic operations.
        #stringr::str_replace( "\\ +\\ ",             "+" ) %>%
        stringr::str_replace( "(\\ \\*)|(\\*\\ )",             "*" ) %>%
        
        # Clean up scraps caused by previous transforms.
        stringr::str_replace( "\\ ?-\\ ?",             "" )
        
        

)

n_row_display <- 200
options(repr.matrix.max.rows = n_row_display)
qry %>% distinct() %>% collect()
# Out:
#      medicationquantity
# 1    112 tablet(s) - 500 mg
# 2    7 tablets - 500 mg
# 3    420 tablet
# 4    126 tablet(s)
# 5    14 x tablets
# 6    3 tablet - 80 mg
# 7    160 tablets
# 8    256 tablet
# 9    320 tablet
# 10   3*112 tablets
# 11   14 tablet - 80mg
# 12   9*28 tablet(s) - 500 mg
# 13   3x28 tablet
# 14   14 tablets- NOMAD
# 15   280 tablets - 80 mg
# 16   83 tablet(s)
# 17   57 tablet
# 18   56*2 tablet - 80 mg
# 19   Total: 2 tablet
# 20   10*28 tablet - 500 mg
# 21   90.00 tablet(s)
# 22   152 tablet
# 23   3 x 84 tablets
# 24   16 tablet - 850 mg
# 25   840 tablets
# 26   7 tablets - 80 mg
# 27   56 tablets - 850 mg
# 28   14 tablets
# 29   14 tablets - 80 mg
# 30   42 tablet
# 31   336 tablet - 500 mg
# 32   112 tablet - 750 mg
# 33   300 - tablet(s)
# 34   3*28 tablet
# 35   168 tablet(s) - 30 mg
# 36   56 - tablets
# 37   10.5 tablets
# 38   56 tablet - 750 mg
# 39   8*28 tablets - 500 mg
# 40   6 tablets
# 41   6*28 tablet
# 42   53 tablets
# 43   116 tablet(s)
# 44   60tablet(s)
# 45   30 tabs tablets
# 46   90 tablet(s)x 2
# 47   28*9 tablets - 500 mg
# 48   60 tablet(s)   Temp.
# 49   104 tablet(s)
# 50   380 tablet
# 51   270 tablets - 100 mg
# 52   224 tablet   Temp. - 750 mg
# 53   Total: 0.5 tablet
# 54   224 tablet - 80mg
# 55   56*2 tablet(s)
# 56   28 tablet - 80 mg
# 57   21 tablets - 500 mg
# 58   252 tablets - 500 mg
# 59   8*28 tablet(s)
# 60   270 tablet(s)
# 61   336 tablet(s) - 80 mg
# 62   9 tablet
# 63   8*28 tablet(s) - 500 mg
# 64   75 tablet(s) - 80 mg
# 65   28 tablet(s) NOMAD
# 66   112 tablet - 4 mg + 1 gram
# 67   150 tablet(s) - 80 mg
# 68   265 tablets
# 69   40 tablets
# 70   3*28 tablets - 80 mg
# 71   168 - tablet
# 72   27 tablets
# 73   1008 tablets
# 74   132 tablet(s)
# 75   61 tablet
# 76   336 x tablets
# 77   5*56 tablet - 500 mg
# 78   360 tablet(s)   Temp.
# 79   28*12 tablet(s)   Temp.
# 80   24 tablets - 80 mg
# 81   528 tablet
# 82   21 tablet(s) NOMAD
# 83   6272 tablets
# 84   284 tablet(s)
# 85   10 tablet(s) - 500 mg
# 86   20 - tablet(s)
# 87   67 tablet
# 88   6*56 tablet - 850 mg
# 89   112 (tablets)
# 90   167 tablet
# 91   2 X 112 tablets
# 92   224 tablet(s)
# 93   84 x tablets
# 94   90 tablet(s)
# 95   112 tablets - 500 mg
# 96   2 packs of 100 tablet(s)
# 97   56 tablet(s) - 80 mg
# 98   56 tablet - 15 mg + 850 mg
# 99   12*28 tablets - 500 mg
# 100  15 tablets
# ⋮    ⋮
# 1960 426 tablet(s)
# 1961 168tablet(s)
# 1962 9 packs of 84 tablet(s)
# 1963 105 tablets - 850 mg
# 1964 224 tablets - 80 mg
# 1965 28 tablets - 80mg
# 1966 224  tablets - 80mg
# 1967 60 - tablet(s)
# 1968 3 packs of 30 tablet(s)
# 1969 2*28 tablet(s) - 15 mg
# 1970 254tablet(s)
# 1971 240 tablets - 80mg
# 1972 31 tablets
# 1973 8*28 tablet
# 1974 64 tablets - 500 mg
# 1975 63 tablet(s) - 500 mg
# 1976 3*56 tablet - 850 mg
# 1977 94 - tablet(s)
# 1978 2 x 28 tablet(s)
# 1979 56x3tablets- 500 mg
# 1980 98 tablet - 2 mg + 1 gram
# 1981 34 tablet(s) - 80 mg
# 1982 133 tablet
# 1983 84 tablets)
# 1984 220 tablets
# 1985 22 tablet - 500 mg
# 1986 1 tablet(s) - 500 mg
# 1987 2860 tablet
# 1988 120 - tablet(s)
# 1989 14 tablet - 500 mg
# 1990 15 tablets - 80 mg
# 1991 1 pack of 30 tablet(s)
# 1992 27 tablet
# 1993 84 tablets NOMAD
# 1994 340 tablets
# 1995 2*28 tablet
# 1996 7 packs of 28 tablet(s)
# 1997 180 tablets - 850 mg
# 1998 6 tablet - 500 mg
# 1999 59 tablets
# 2000 2*56 tablet(s)
# 2001 250 tablet(s)
# 2002 242 tablet
# 2003 305 tablet
# 2004 150 tablet - 500 mg
# 2005 105 tablets - 80 mg
# 2006 3.5 tablets - 80 mg
# 2007 17 tablet
# 2008 140tablet
# 2009 3*60 tablet - 80 mg
# 2010 99 tablet
# 2011 41 tablets
# 2012 15 packs of 28 tablet(s)
# 2013 10 packs of 60 tablet(s)
# 2014 59 tablet
# 2015 112*2 tablets - 80mg
# 2016 2 x 84 tablet
# 2017 56 tablets
# 2018 21 tablet(s)
# 2019 60 tablets - 80 mg
# 2020 56 tablet(s) - 15 mg
# 2021 7 tablets
# 2022 3 packs of 28 tablet(s)
# 2023 280 tablets
# 2024 120 tablet
# 2025 28 tablet - 850 mg
# 2026 28 tablet - 30 mg
# 2027 7 tablet - 30 mg
# 2028 11 tablet - 80 mg
# 2029 56 tablets NOMAD
# 2030 2*28 tablet(s) - 45 mg
# 2031 4*28 tablet - 80 mg
# 2032 19 tablets
# 2033 4*84 tablets - 500 mg
# 2034 300 tablet(s) - 500 mg
# 2035 126 - tablet(s)
# 2036 248 tablet
# 2037 6 packs of 84 tablet(s)
# 2038 200 x tablets
# 2039 240 x tablet(s)
# 2040 11256 tablet
# 2041 178 tablet
# 2042 98 tablet(s) - 80 mg
# 2043 21 tablets - 850 mg
# 2044 30 tablet(s) - 500 mg
# 2045 28 tabs tablets
# 2046 24*4 tablet - 500 mg
# 2047 184 tablet(s)
# 2048 112*3 tablet - 500 mg
# 2049 2*56 tablet(s) - 500 mg
# 2050 28*6 tablet - 500 mg
# 2051 112 tablet   Temp. - 500 mg
# 2052 30 tablet(s) - 50 mg
# 2053 28tablet(s)
# 2054 672 tablet - 500 mg
# 2055 294 tablet
# 2056 96 tablets NOMAD
# 2057 270 tabs tablets
# 2058 165 tablet
# 2059 56 tabletss)
#      transformed
# 1     QUANT = (4 MONTHS)
# 2    7
# 3    420
# 4    126
# 5    14  MULTI = (1 TIMES)
# 6    3
# 7    160
# 8    2 QUANT = (2 MONTHS)
# 9    320
# 10    MULTI = (3 TIMES) QUANT = (4 MONTHS)
# 11   14
# 12    MULTI = (9 TIMES) QUANT = (1 MONTHS)
# 13   3 MULTI = (1 TIMES) QUANT = (1 MONTHS)
# 14   14nomad
# 15    QUANT = (10 MONTHS)
# 16   83
# 17   57
# 18    QUANT = (2 MONTHS) MULTI = (2 TIMES)
# 19   total: 2
# 20    MULTI = (10 TIMES) QUANT = (1 MONTHS)
# 21   90.00
# 22   152
# 23   3  MULTI = (1 TIMES)  QUANT = (3 MONTHS)
# 24   16
# 25   840
# 26   7
# 27    QUANT = (2 MONTHS)
# 28   14
# 29   14
# 30   42
# 31    QUANT = (12 MONTHS)
# 32    QUANT = (4 MONTHS)
# 33   300
# 34    MULTI = (3 TIMES) QUANT = (1 MONTHS)
# 35    QUANT = (6 MONTHS)
# 36    QUANT = (2 MONTHS)
# 37   10.5
# 38    QUANT = (2 MONTHS)
# 39    MULTI = (8 TIMES) QUANT = (1 MONTHS)
# 40   6
# 41    MULTI = (6 TIMES) QUANT = (1 MONTHS)
# 42   53
# 43   116
# 44   60
# 45   30
# 46   90  MULTI = (1 TIMES)  2
# 47    QUANT = (1 MONTHS) MULTI = (9 TIMES)
# 48   60    temp.
# 49   104
# 50   380
# 51   270
# 52    QUANT = (8 MONTHS)    temp.
# 53   total: 0.5
# 54    QUANT = (8 MONTHS)
# 55    QUANT = (2 MONTHS) MULTI = (2 TIMES)
# 56    QUANT = (1 MONTHS)
# 57   21
# 58    QUANT = (9 MONTHS)
# 59    MULTI = (8 TIMES) QUANT = (1 MONTHS)
# 60   270
# 61    QUANT = (12 MONTHS)
# 62   9
# 63    MULTI = (8 TIMES) QUANT = (1 MONTHS)
# 64   75
# 65    QUANT = (1 MONTHS)  nomad
# 66    QUANT = (4 MONTHS)  + 1
# 67   150
# 68   265
# 69   40
# 70    MULTI = (3 TIMES) QUANT = (1 MONTHS)
# 71    QUANT = (6 MONTHS)
# 72   27
# 73   1008
# 74   132
# 75   61
# 76    QUANT = (12 MONTHS)  MULTI = (1 TIMES)
# 77    MULTI = (5 TIMES) QUANT = (2 MONTHS)
# 78   360    temp.
# 79    QUANT = (1 MONTHS) MULTI = (12 TIMES)    temp.
# 80   24
# 81   5 QUANT = (1 MONTHS)
# 82   21  nomad
# 83   6272
# 84   2 QUANT = (3 MONTHS)
# 85   10
# 86   20
# 87   67
# 88    MULTI = (6 TIMES) QUANT = (2 MONTHS)
# 89    QUANT = (4 MONTHS)
# 90   167
# 91   2  MULTI = (1 TIMES)  QUANT = (4 MONTHS)
# 92    QUANT = (8 MONTHS)
# 93    QUANT = (3 MONTHS)  MULTI = (1 TIMES)
# 94   90
# 95    QUANT = (4 MONTHS)
# 96    MULTI = (2 TIMES) 100
# 97    QUANT = (2 MONTHS)
# 98    QUANT = (2 MONTHS)  +
# 99    MULTI = (12 TIMES) QUANT = (1 MONTHS)
# 100  15
# ⋮    ⋮
# 1960 426
# 1961 168
# 1962  MULTI = (9 TIMES) QUANT = (3 MONTHS)
# 1963 105
# 1964  QUANT = (8 MONTHS)
# 1965  QUANT = (1 MONTHS)
# 1966  QUANT = (8 MONTHS)
# 1967 60
# 1968  MULTI = (3 TIMES) 30
# 1969  MULTI = (2 TIMES) QUANT = (1 MONTHS)
# 1970 254
# 1971 240
# 1972 31
# 1973  MULTI = (8 TIMES) QUANT = (1 MONTHS)
# 1974 64
# 1975 63
# 1976  MULTI = (3 TIMES) QUANT = (2 MONTHS)
# 1977 94
# 1978 2  MULTI = (1 TIMES)  QUANT = (1 MONTHS)
# 1979  QUANT = (2 MONTHS) MULTI = (1 TIMES) 3
# 1980 98  + 1
# 1981 34
# 1982 133
# 1983  QUANT = (3 MONTHS)
# 1984 220
# 1985 22
# 1986 1
# 1987 2860
# 1988 120
# 1989 14
# 1990 15
# 1991  MULTI = (1 TIMES) 30
# 1992 27
# 1993  QUANT = (3 MONTHS)  nomad
# 1994 340
# 1995  MULTI = (2 TIMES) QUANT = (1 MONTHS)
# 1996  MULTI = (7 TIMES) QUANT = (1 MONTHS)
# 1997 180
# 1998 6
# 1999 59
# 2000  MULTI = (2 TIMES) QUANT = (2 MONTHS)
# 2001 250
# 2002 242
# 2003 305
# 2004 150
# 2005 105
# 2006 3.5
# 2007 17
# 2008 140
# 2009  MULTI = (3 TIMES) 60
# 2010 99
# 2011 41
# 2012 15*QUANT = (1 MONTHS)
# 2013  MULTI = (10 TIMES) 60
# 2014 59
# 2015  QUANT = (4 MONTHS) MULTI = (2 TIMES)
# 2016 2  MULTI = (1 TIMES)  QUANT = (3 MONTHS)
# 2017  QUANT = (2 MONTHS)
# 2018 21
# 2019 60
# 2020  QUANT = (2 MONTHS)
# 2021 7
# 2022  MULTI = (3 TIMES) QUANT = (1 MONTHS)
# 2023  QUANT = (10 MONTHS)
# 2024 120
# 2025  QUANT = (1 MONTHS)
# 2026  QUANT = (1 MONTHS)
# 2027 7
# 2028 11
# 2029  QUANT = (2 MONTHS)  nomad
# 2030  MULTI = (2 TIMES) QUANT = (1 MONTHS)
# 2031  MULTI = (4 TIMES) QUANT = (1 MONTHS)
# 2032 19
# 2033  MULTI = (4 TIMES) QUANT = (3 MONTHS)
# 2034 300
# 2035 126
# 2036 248
# 2037  MULTI = (6 TIMES) QUANT = (3 MONTHS)
# 2038 200  MULTI = (1 TIMES)
# 2039 240  MULTI = (1 TIMES)
# 2040  QUANT = (4 MONTHS) QUANT = (2 MONTHS)
# 2041 178
# 2042 98
# 2043 21
# 2044 30
# 2045  QUANT = (1 MONTHS)
# 2046 24 MULTI = (4 TIMES)
# 2047 1 QUANT = (3 MONTHS)
# 2048  QUANT = (4 MONTHS) MULTI = (3 TIMES)
# 2049  MULTI = (2 TIMES) QUANT = (2 MONTHS)
# 2050  QUANT = (1 MONTHS) MULTI = (6 TIMES)
# 2051  QUANT = (4 MONTHS)    temp.
# 2052 30
# 2053 28
# 2054 672
# 2055 294
# 2056 96  nomad
# 2057 270
# 2058 165
# 2059  QUANT = (2 MONTHS) s

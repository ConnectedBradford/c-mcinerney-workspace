# %% [markdown]
# # Create feature sets.
#
# The purpose of this notebook is to call all the notebooks that contribute to creating the features.

# %%
# Initial, major query of the databse.
# %run "UNSEEN_create_feature_sets_base.ipynb"
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2002, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow)
#    2001 try:
# -> 2002     new_values = self.values.fillna(
#    2003         value=value, method=None, limit=limit, copy=copy
#    2004     )
#    2005 except TypeError:
#    2006     # 3rd party EA that has not implemented copy keyword yet
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:244, in BaseMaskedArray.fillna(self, value, method, limit, copy)
#     243             new_values = self[:]
# --> 244         new_values[mask] = value
#     245 else:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:292, in BaseMaskedArray.__setitem__(self, key, value)
#     291 else:
# --> 292     value = self._validate_setitem_value(value)
#     293     self._data[key] = value
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:283, in BaseMaskedArray._validate_setitem_value(self, value)
#     279     # TODO: unsigned checks
#     280
#     281 # Note: without the "str" here, the f-string rendering raises in
#     282 #  py38 builds.
# --> 283 raise TypeError(f"Invalid value '{str(value)}' for dtype {self.dtype}")
#
# TypeError: Invalid value '0' for dtype boolean
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File /var/tmp/ipykernel_21460/662710122.py:5
#       1 feature_set_array = \
#       2     feature_set_array_pt1.merge(
#       3         feature_set_array_pt2, on = 'person_id', how = 'left').merge(
#       4             feature_set_array_pt3, on = 'person_id', how = 'left').merge(
# ----> 5                 feature_set_array_pt4, on = 'person_id', how = 'left').fillna(0)
#       6 # Double-check that all exclusions have been applied.
#       7 feature_set_array.drop(feature_set_array[~feature_set_array.person_id.isin(caseness_array.person_id)].index, inplace=True)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:7297, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7295         new_data = result._mgr
#    7296     else:
# -> 7297         new_data = self._mgr.fillna(
#    7298             value=value, limit=limit, inplace=inplace, downcast=downcast
#    7299         )
#    7300 elif isinstance(value, ABCDataFrame) and self.ndim == 2:
#    7301     new_data = self.where(self.notna(), value)._mgr
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/base.py:173, in DataManager.fillna(self, value, limit, inplace, downcast)
#     169 if limit is not None:
#     170     # Do this validation even if we go through one of the no-op paths
#     171     limit = libalgos.validate_limit(None, limit=limit)
# --> 173 return self.apply_with_block(
#     174     "fillna",
#     175     value=value,
#     176     limit=limit,
#     177     inplace=inplace,
#     178     downcast=downcast,
#     179     using_cow=using_copy_on_write(),
#     180 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2008, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow)
#    2005 except TypeError:
#    2006     # 3rd party EA that has not implemented copy keyword yet
#    2007     refs = None
# -> 2008     new_values = self.values.fillna(value=value, method=None, limit=limit)
#    2009     # issue the warning *after* retrying, in case the TypeError
#    2010     #  was caused by an invalid fill_value
#    2011     warnings.warn(
#    2012         # GH#53278
#    2013         "ExtensionArray.fillna added a 'copy' keyword in pandas "
#    (...)
#    2019         stacklevel=find_stack_level(),
#    2020     )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:244, in BaseMaskedArray.fillna(self, value, method, limit, copy)
#     242         else:
#     243             new_values = self[:]
# --> 244         new_values[mask] = value
#     245 else:
#     246     if copy:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:292, in BaseMaskedArray.__setitem__(self, key, value)
#     290     self._mask[key] = True
#     291 else:
# --> 292     value = self._validate_setitem_value(value)
#     293     self._data[key] = value
#     294     self._mask[key] = False
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:283, in BaseMaskedArray._validate_setitem_value(self, value)
#     278         return value
#     279     # TODO: unsigned checks
#     280
#     281 # Note: without the "str" here, the f-string rendering raises in
#     282 #  py38 builds.
# --> 283 raise TypeError(f"Invalid value '{str(value)}' for dtype {self.dtype}")
#
# TypeError: Invalid value '0' for dtype boolean
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2002, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow)
#    2001 try:
# -> 2002     new_values = self.values.fillna(
#    2003         value=value, method=None, limit=limit, copy=copy
#    2004     )
#    2005 except TypeError:
#    2006     # 3rd party EA that has not implemented copy keyword yet
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:244, in BaseMaskedArray.fillna(self, value, method, limit, copy)
#     243             new_values = self[:]
# --> 244         new_values[mask] = value
#     245 else:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:292, in BaseMaskedArray.__setitem__(self, key, value)
#     291 else:
# --> 292     value = self._validate_setitem_value(value)
#     293     self._data[key] = value
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:283, in BaseMaskedArray._validate_setitem_value(self, value)
#     279     # TODO: unsigned checks
#     280
#     281 # Note: without the "str" here, the f-string rendering raises in
#     282 #  py38 builds.
# --> 283 raise TypeError(f"Invalid value '{str(value)}' for dtype {self.dtype}")
#
# TypeError: Invalid value '0' for dtype boolean
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Initial, major query of the databse.
# ----> 2 get_ipython().run_line_magic('run', '"UNSEEN_create_feature_sets_base.ipynb"')
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/magics/execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2981, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2979 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2980 if raise_exceptions:
# -> 2981     result.raise_error()
#    2982 elif not result.success:
#    2983     break
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:294, in ExecutionResult.raise_error(self)
#     292     raise self.error_before_exec
#     293 if self.error_in_exec is not None:
# --> 294     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /var/tmp/ipykernel_21460/662710122.py:5
#       1 feature_set_array = \
#       2     feature_set_array_pt1.merge(
#       3         feature_set_array_pt2, on = 'person_id', how = 'left').merge(
#       4             feature_set_array_pt3, on = 'person_id', how = 'left').merge(
# ----> 5                 feature_set_array_pt4, on = 'person_id', how = 'left').fillna(0)
#       6 # Double-check that all exclusions have been applied.
#       7 feature_set_array.drop(feature_set_array[~feature_set_array.person_id.isin(caseness_array.person_id)].index, inplace=True)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:7297, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7295         new_data = result._mgr
#    7296     else:
# -> 7297         new_data = self._mgr.fillna(
#    7298             value=value, limit=limit, inplace=inplace, downcast=downcast
#    7299         )
#    7300 elif isinstance(value, ABCDataFrame) and self.ndim == 2:
#    7301     new_data = self.where(self.notna(), value)._mgr
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/base.py:173, in DataManager.fillna(self, value, limit, inplace, downcast)
#     169 if limit is not None:
#     170     # Do this validation even if we go through one of the no-op paths
#     171     limit = libalgos.validate_limit(None, limit=limit)
# --> 173 return self.apply_with_block(
#     174     "fillna",
#     175     value=value,
#     176     limit=limit,
#     177     inplace=inplace,
#     178     downcast=downcast,
#     179     using_cow=using_copy_on_write(),
#     180 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2008, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow)
#    2005 except TypeError:
#    2006     # 3rd party EA that has not implemented copy keyword yet
#    2007     refs = None
# -> 2008     new_values = self.values.fillna(value=value, method=None, limit=limit)
#    2009     # issue the warning *after* retrying, in case the TypeError
#    2010     #  was caused by an invalid fill_value
#    2011     warnings.warn(
#    2012         # GH#53278
#    2013         "ExtensionArray.fillna added a 'copy' keyword in pandas "
#    (...)
#    2019         stacklevel=find_stack_level(),
#    2020     )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:244, in BaseMaskedArray.fillna(self, value, method, limit, copy)
#     242         else:
#     243             new_values = self[:]
# --> 244         new_values[mask] = value
#     245 else:
#     246     if copy:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:292, in BaseMaskedArray.__setitem__(self, key, value)
#     290     self._mask[key] = True
#     291 else:
# --> 292     value = self._validate_setitem_value(value)
#     293     self._data[key] = value
#     294     self._mask[key] = False
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:283, in BaseMaskedArray._validate_setitem_value(self, value)
#     278         return value
#     279     # TODO: unsigned checks
#     280
#     281 # Note: without the "str" here, the f-string rendering raises in
#     282 #  py38 builds.
# --> 283 raise TypeError(f"Invalid value '{str(value)}' for dtype {self.dtype}")
#
# TypeError: Invalid value '0' for dtype boolean

# %%
# Append feature sets that are calculated from the base.
# %run "UNSEEN_create_feature_sets_appendix1.ipynb"

# %%
# Append feature sets that are based on entropy statistics.
# %run "UNSEEN_create_feature_sets_appendix2.ipynb"

# %%
# Append feature sets that are collations of oter feature sets.
# %run "UNSEEN_create_feature_sets_appendix3.ipynb"

# %%
# Append feature sets that are combinations of the collations.
# %run "UNSEEN_create_feature_sets_appendix4.ipynb"

# %% [markdown]
# ## Show feature names.
#
# Below I print the names of the features that are in `feature_set_array`. Most feature sets that I evaluate are combinations of these feature sets, as explained in `UNSEEN_create_feature_sets_appendix3.ipynb` and `UNSEEN_create_feature_sets_appendix4.ipynb`.

# %%
# %store -r
print(f'The feature sets are {list(feature_set_array.columns)}')
